# %% [markdown]
# ## 数据处理, 数据保存到npz中
#
# 1. train, vali, testa 的词id np array
# 2. train, vali, test 的标签保存为 np array
# 3. word2id保存为json
# 4. embedding 保存为 np array

# %%
import pandas as pd
import numpy as np
EMBEDDING_FILE = '../inputs/fasttextwordvec.vec'
train = pd.read_csv("../inputs/train.csv")
test = pd.read_csv("../inputs/testa.csv")
val = pd.read_csv("../inputs/vali.csv")
X_train = train["content"].fillna("无").str.lower()
X_val = val["content"].fillna("无").str.lower()
X_test = test["content"].fillna("无").str.lower()

# %%
import pickle

# %% [markdown]
# ## 处理词向量

# %%
word2id = pickle.load(open("../inputs/word2id.pkl", 'rb'))

# %%
# 数据参数
max_features=65462
maxlen=200
embed_size=300

# %%
embeddings_index = {}
with open(EMBEDDING_FILE,encoding='utf8') as f:
    for line in f:
        values = line.rstrip().rsplit(' ')
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
word_index = word2id
#prepare embedding matrix
num_words = max_features

# %%
embedding_matrix = np.random.randn(num_words, embed_size) * 0.01
for word, i in word_index.items():
    if i >= max_features:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
# 保存embedding
np.savez_compressed("../inputs/fasttextwordvec.npz",vector=embedding_matrix)

# %% [markdown]
# ## 保存Y

# %%
from tensorflow.keras.utils import to_categorical

from typing import List

columns = train.columns.tolist()[2:]
def get_y(df:pd.DataFrame, cols:List[str]=columns) -> List[np.array]:
    y_dict = dict()
    for col in cols:
        y = df[col].values + 2
        y_ = to_categorical(y, num_classes=4)
        y_dict[col] = y_
    return y_dict

# %%
y_train = get_y(train)
y_val = get_y(val)

# %%
np.savez_compressed("../inputs/Y_train.npz",**y_train)
np.savez_compressed("../inputs/Y_valid.npz",**y_val)

# %%
pickle.dump(columns, open("../inputs/columns.pkl", 'wb'))

# %% [markdown]
# ## 保存X

# %%
import tensorflow as tf

def transform_data_to_id(x_arr, word2id):
    data = []

    def map_word_to_id(word):
        output = []
        if word in word2id:
            output.append(word2id[word])
        else:
            chars = list(word)
            for char in chars:
                if char in word2id:
                    output.append(word2id[char])
                else:
                    output.append(1)
        return output

    def map_sent_to_id(sent):
        output = []
        for word in sent:
            output.extend(map_word_to_id(word))
        return output
    for s in x_arr:
        data.append(map_sent_to_id(s))
    
    return data

# %%
x_val = transform_data_to_id(X_val, word2id)

# %%
import keras
pad_sequence = keras.preprocessing.sequence.pad_sequences

# %%
X_val = transform_data_to_id(X_val, word2id)
X_val = pad_sequence(X_val,maxlen=maxlen,padding='pre',truncating='pre',value = 0)
X_train = transform_data_to_id(X_train, word2id)
X_train = pad_sequence(X_train,maxlen=maxlen,padding='pre',truncating='pre',value = 0)
X_test = transform_data_to_id(X_test, word2id)
X_test = pad_sequence(X_test,maxlen=maxlen,padding='pre',truncating='pre',value = 0)

# %%
np.savez_compressed("../inputs/X_train.npz",X = X_train)
np.savez_compressed("../inputs/X_valid.npz",X = X_val)
np.savez_compressed("../inputs/X_test.npz",X = X_test)

# %%
columns

# %% [markdown]
# ## 模型

# %%
import torch as t
import time

class BasicModule(t.nn.Module):
    '''
    封装了nn.Module,主要是提供了save和load两个方法
    '''

    def __init__(self):
        super(BasicModule,self).__init__()
        self.model_name=str(type(self))# 默认名字

    def load(self, path,change_opt=True):
        print("Loading model from " + path)
        data = t.load(path)
        self.load_state_dict(data)
        return self.cuda()

    def save(self, name=None,new=False):
        prefix = '../ckpt/' + self.model_name + '_'
        if name is None:
            name = time.strftime('%m%d_%H:%M:%S.pth')
        path = prefix+name +'.pt'
        data=self.state_dict()
        t.save(data, path)
        print("Saving model to "+ path)
        return path

    def get_optimizer(self,lr1,lr2=0,weight_decay = 0):
        ignored_params = list(map(id, self.encoder.parameters()))
        base_params = filter(lambda p: id(p) not in ignored_params,
                        self.parameters())
        if lr2 is None: lr2 = lr1*0.5 
        optimizer = t.optim.Adam([
                dict(params=base_params,weight_decay = weight_decay,lr=lr1),
                {'params': self.encoder.parameters(), 'lr': lr2}
            ])
        return optimizer

# %%
from torch import nn
from collections import OrderedDict

class Inception(nn.Module):
    def __init__(self,cin,co,relu=True,norm=True):
        super(Inception, self).__init__()
        assert(co%4==0)
        cos=[co//4]*4
        self.activa=nn.Sequential()
        if norm:self.activa.add_module('norm',nn.BatchNorm1d(co))
        if relu:self.activa.add_module('relu',nn.ReLU(True))
        self.branch1 =nn.Sequential(OrderedDict([
            ('conv1', nn.Conv1d(cin,cos[0], 1,stride=1)),
            ])) 
        self.branch2 =nn.Sequential(OrderedDict([
            ('conv1', nn.Conv1d(cin,cos[1], 1)),
            ('norm1', nn.BatchNorm1d(cos[1])),
            ('relu1', nn.ReLU(inplace=True)),
            ('conv3', nn.Conv1d(cos[1],cos[1], 3,stride=1,padding=1)),
            ]))
        self.branch3 =nn.Sequential(OrderedDict([
            ('conv1', nn.Conv1d(cin,cos[2], 3,padding=1)),
            ('norm1', nn.BatchNorm1d(cos[2])),
            ('relu1', nn.ReLU(inplace=True)),
            ('conv3', nn.Conv1d(cos[2],cos[2], 5,stride=1,padding=2)),
            ]))
        self.branch4 =nn.Sequential(OrderedDict([
            #('pool',nn.MaxPool1d(2)),
            ('conv3', nn.Conv1d(cin,cos[3], 3,stride=1,padding=1)),
            ]))
    def forward(self,x):
        branch1=self.branch1(x)
        branch2=self.branch2(x)
        branch3=self.branch3(x)
        branch4=self.branch4(x)
        result=self.activa(torch.cat((branch1,branch2,branch3,branch4),1))
        return result

# %%
import copy
import pickle as pkl
class CNNText_inception(BasicModule):
    def __init__(self, opt):
        super(CNNText_inception, self).__init__()
        incept_dim=opt.inception_dim
        self.label_list = pkl.load(open(opt.label_list_pkl, "rb"))
        self.model_name = 'CNNText_inception'
        self.opt=opt
        self.encoder = nn.Embedding(opt.vocab_size,opt.embedding_dim)
        self.content_conv=nn.Sequential(
            Inception(opt.embedding_dim,incept_dim),#(batch_size,64,opt.content_seq_len)->(batch_size,64,(opt.content_seq_len)/2)
            #Inception(incept_dim,incept_dim),#(batch_size,64,opt.content_seq_len/2)->(batch_size,32,(opt.content_seq_len)/4)
            Inception(incept_dim,incept_dim),
            nn.MaxPool1d(opt.content_seq_len)
        )
        self.fc_sub = nn.Sequential(
            nn.Linear(incept_dim,opt.linear_hidden_size),
            nn.BatchNorm1d(opt.linear_hidden_size),
            nn.ReLU(inplace=True),
            nn.Linear(opt.linear_hidden_size,opt.num_classes)
        )
        self.fc = nn.ModuleDict({label: copy.deepcopy(self.fc_sub) for label in self.label_list}
        )
        if opt.embedding_path:
            print('load embedding')
            self.encoder.weight.data.copy_(t.from_numpy(np.load(opt.embedding_path)['vector']))
    def forward(self, content):
        content = self.encoder(content)
        content_out=self.content_conv(content.permute(0,2,1))        
        out = content_out.view(content_out.size(0), -1)
        out_dict = {label: self.fc[label](out) for label in self.label_list}
        return out_dict

# %%
import torch as t
import numpy as np
from torch import nn


def kmax_pooling(x, dim, k):
    index = x.topk(k, dim = dim)[1].sort(dim = dim)[0]
    return x.gather(dim, index)

class RCNN(BasicModule): 
    def __init__(self, opt ):
        super(RCNN, self).__init__()
        self.model_name = 'RCNN'
        self.opt=opt
        self.label_list = pkl.load(open(opt.label_list_pkl, "rb"))
        kernel_size = opt.kernel_size
        self.encoder = nn.Embedding(opt.vocab_size,opt.embedding_dim)

        self.title_lstm = nn.LSTM(input_size = opt.embedding_dim,\
                            hidden_size = opt.hidden_size,
                            num_layers = opt.num_layers,
                            bias = True,
                            batch_first = False,
                            dropout = 0.5,
                            bidirectional = True
                            )

        self.content_lstm =nn.LSTM(input_size = opt.embedding_dim,\
                            hidden_size = opt.hidden_size,
                            num_layers = opt.num_layers,
                            bias = True,
                            batch_first = False,
                            # dropout = 0.5,
                            bidirectional = True
                            )

        self.content_conv = nn.Sequential(
            nn.Conv1d(in_channels = opt.hidden_size*2 + opt.embedding_dim,
                      out_channels = opt.content_dim,
                      kernel_size =  kernel_size),
            nn.BatchNorm1d(opt.content_dim),
            nn.ReLU(inplace=True),

            nn.Conv1d(in_channels = opt.content_dim,
                      out_channels = opt.content_dim,
                      kernel_size =  kernel_size),
            nn.BatchNorm1d(opt.content_dim),
            nn.ReLU(inplace=True),
        )

        self.fc_sub = nn.Sequential(
            nn.Linear(opt.kmax_pooling*(opt.content_dim),opt.linear_hidden_size),
            nn.BatchNorm1d(opt.linear_hidden_size),
            nn.ReLU(inplace=True),
            nn.Linear(opt.linear_hidden_size,opt.num_classes)
        )
        self.fc = nn.ModuleDict({label: copy.deepcopy(self.fc_sub) for label in self.label_list}
        )
        if opt.embedding_path:
            self.encoder.weight.data.copy_(t.from_numpy(np.load(opt.embedding_path)['vector']))
            
    def forward(self, content):
        content = self.encoder(content)

        content_out = self.content_lstm(content.permute(1,0,2))[0].permute(1,2,0)
        content_em = (content).permute(0,2,1)
        content_out = t.cat((content_out,content_em),dim=1)
        content_conv_out = kmax_pooling(self.content_conv(content_out),2,self.opt.kmax_pooling)
        out = content_conv_out.view(content_conv_out.size(0), -1)
        out_dict = {label: self.fc[label](out) for label in self.label_list}
        return out_dict

# %% [markdown]
# ## config

# %%
#coding:utf8
import time
import warnings

class ModelConfig(object):
    '''
    并不是所有的配置都生效,实际运行中只根据需求获取自己需要的参数
    '''
    content_dim = 200 #描述的卷积核数
    num_classes = 4 # 类别
    embedding_dim = 300 # embedding大小
    linear_hidden_size = 1024 # 全连接层隐藏元数目
    kmax_pooling = 2# k
    hidden_size = 256 #LSTM hidden size
    num_layers=2 #LSTM layers
    inception_dim = 512 #inception的卷积核数
    
    vocab_size = 65462
    kernel_size = 3 #单尺度卷积核
    kernel_sizes = [2,3,4] #多尺度卷积核
    content_seq_len = 200 
    label_list_pkl = "../inputs/columns.pkl"
    embedding_path = '../inputs/fasttextwordvec.npz' # Embedding
    
    
class ModelConfig2(object):
    '''
    并不是所有的配置都生效,实际运行中只根据需求获取自己需要的参数
    '''
    content_dim = 100 #描述的卷积核数
    num_classes = 4 # 类别
    embedding_dim = 300 # embedding大小
    linear_hidden_size = 128 # 全连接层隐藏元数目
    kmax_pooling = 2# k
    hidden_size = 128 #LSTM hidden size
    num_layers=2 #LSTM layers
    inception_dim = 128 #inception的卷积核数

    vocab_size = 65462
    kernel_size = 3 #单尺度卷积核
    kernel_sizes = [2,3,4] #多尺度卷积核
    content_seq_len = 200 
    label_list_pkl = "../inputs/columns.pkl"
    embedding_path = '../inputs/fasttextwordvec.npz' # Embedding

# %%
# modelopt = ModelConfig()
modelopt = ModelConfig()

# %%
import numpy as np
import pickle as pkl
model = RCNN(modelopt)

# %% [markdown]
# ## Dataset

# %%
from torch.utils import data
## 数据集，对于训练集生成X:wordid_list,Y:dict of label one hot vector
## 对于验证集只生成 X, Y直接通过Dataset.Y[label]获取相应的标签
## 训练数据同时有数据集增强：随机dropout,打散顺序

class FGSentimetDataset(data.Dataset):
    def __init__(self, X_npz, Y_npz, label_pkl, augument=False, training=False, dropout_rate=0.3, augument_rate=0.4):
        self.dropout_rate = dropout_rate
        self.augument_rate = augument_rate
        self.augument=augument
        self.training = training
        self.label_list = pickle.load(open(label_pkl, 'rb'))
        self.X = np.load(X_npz)['X']
        dataset = np.load(Y_npz)
        self.Y = {}
        for col in self.label_list:
            self.Y[col] = dataset[col]
        self._len = self.X.shape[0]
    def shuffle(self,d):
        return np.random.permutation(d.tolist())

    def dropout(self,d,p=0.5):
        len_ = len(d)
        index = np.random.choice(len_,int(len_*p))
        d[index]=0
        return d     


    def __getitem__(self,index):
        
        content =  self.X[index]
    
        if self.training:  
            if self.augument :
                augument=random.random()

                if augument>self.augument_rate:
                    content = self.dropout(content,p=self.dropout_rate)
                else:
                    content = self.shuffle(content)

            data =t.from_numpy(content).long()
            label_dict = {label:t.from_numpy(self.Y[label][index]).long() for label in self.label_list}
            return data, label_dict
        else:
            return t.from_numpy(content).long()

    def __len__(self):
        return self._len

# %% [markdown]
# ## 验证函数

# %%
from collections import defaultdict  
from sklearn import metrics
import torch
import torch.utils.data
import json

# %%
import pickle
loss_function = nn.CrossEntropyLoss()
Train_dataset = FGSentimetDataset("../inputs/X_train.npz","../inputs/Y_train.npz", "../inputs/columns.pkl", augument=False, training=True)

# %%
Valid_dataset =  FGSentimetDataset("../inputs/X_valid.npz","../inputs/Y_valid.npz", "../inputs/columns.pkl", augument=False, training=False)

# %%
trainloader = torch.utils.data.DataLoader(Train_dataset,
                    batch_size = 512,
                    shuffle = True,
                    num_workers = 8,
                    pin_memory = True
                    )

# %%
validloader = torch.utils.data.DataLoader(Valid_dataset,
                    batch_size = 512,
                    shuffle = False,
                    num_workers = 1,
                    pin_memory = True
                    )

# %%
def eval_metrics(y_pred_dict, y_true_dict):
    accuracys = {}
    f1s = {}
    for col, y_pred in y_pred_dict.items():
        # accuracys[col] = metrics.accuracy_score(y_true_dict[col], y_pred)
        f1s[col] = metrics.f1_score(y_true_dict[col], y_pred, average='macro')

    return f1s

def eval(model, valiloader,y_true, use_cuda=True):
    
    model.eval()
    y_true_ = {}
    y_pred = defaultdict(list)
    for bx in validloader:
        if use_cuda:
            bx =  bx.cuda()
        y_pre = model(bx)
        for col in model.label_list:
            y_label = torch.max(y_pre[col], 1)[1].data
            y_pred[col].extend(y_label.tolist())
            y_true_[col] = np.argmax(y_true[col], 1)
    f1s = eval_metrics(y_pred, y_true_)
    print(json.dumps(f1s, indent=4, sort_keys=True))
    return np.mean(list(f1s.values()))

#scores = eval(model,validloader, Valid_dataset.Y)

# %%
import tqdm
import random
best_score = 0
lr = 5e-3
lr2 = 1e-3
lr_decay = 0.9
early_stops = 20
i = 0
optimizer = model.get_optimizer(lr, lr2,lr_decay)
model.cuda()

for epoch in range(1000):
    model.train()
    print(f"training epoch {epoch}")
    for ii,(content, true_dict) in enumerate(trainloader):
        content = content.cuda()
        optimizer.zero_grad()
        pred_dict = model(content)
        loss = torch.mean(torch.stack([loss_function(pred, torch.max(true_dict[col].cuda(), 1)[1]) for col, pred in pred_dict.items()]))
        loss.backward()
        optimizer.step()
    
    scores = eval(model,validloader, Valid_dataset.Y)
    print(f"epoch: {epoch} LR: {lr}, F1_score:{scores}")
    if scores>best_score:
        print(f"F1-score improved from {best_score} to {scores}")
        i = 0
        best_score = scores
        best_path = model.save(name = str(scores),new=True)

    if scores < best_score:
        i += 1
        print(f"F1-score did not improved from {best_score} for {i} epochs")       
        model.load(best_path,change_opt=False)
        if i > early_stops:
            print("Stop training")
            break
        lr = lr * lr_decay
        lr2= 2e-4 if lr2==0 else  lr2*0.8
        optimizer = model.get_optimizer(lr,lr2,0)
# Out:
# training epoch 0
# {
#     "dish_look": 0.2088283251805264,
#     "dish_portion": 0.17549325025960538,
#     "dish_recommendation": 0.22307351475095077,
#     "dish_taste": 0.17168621957625635,
#     "environment_cleaness": 0.19507236949097415,
#     "environment_decoration": 0.17106705846234815,
#     "environment_noise": 0.20612436816739158,
#     "environment_space": 0.19376505655138623,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.21715190828179212,
#     "location_traffic_convenience": 0.21969951788317077,
#     "others_overall_experience": 0.20089730807577266,
#     "others_willing_to_consume_again": 0.19204237496920423,
#     "price_cost_effective": 0.21621008021795066,
#     "price_discount": 0.19087461874536316,
#     "price_level": 0.16662221629550608,
#     "service_parking_convenience": 0.241788886593679,
#     "service_serving_speed": 0.22901687321602773,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.14232915255853879
# }
# epoch: 0 LR: 0.005, F1_score:0.20093425985453486
# F1-score improved from 0 to 0.20093425985453486
# Saving model to ../ckpt/RCNN_0.20093425985453486.pt
# training epoch 1
# /home/xq/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# {
#     "dish_look": 0.2088283251805264,
#     "dish_portion": 0.17549325025960538,
#     "dish_recommendation": 0.22307351475095077,
#     "dish_taste": 0.17168621957625635,
#     "environment_cleaness": 0.19507236949097415,
#     "environment_decoration": 0.17106705846234815,
#     "environment_noise": 0.20612436816739158,
#     "environment_space": 0.19376505655138623,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.21715190828179212,
#     "location_traffic_convenience": 0.21969951788317077,
#     "others_overall_experience": 0.20089730807577266,
#     "others_willing_to_consume_again": 0.19204237496920423,
#     "price_cost_effective": 0.21621008021795066,
#     "price_discount": 0.19087461874536316,
#     "price_level": 0.16662221629550608,
#     "service_parking_convenience": 0.241788886593679,
#     "service_serving_speed": 0.22901687321602773,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.14272103658536586
# }
# epoch: 1 LR: 0.005, F1_score:0.20095385405587618
# F1-score improved from 0.20093425985453486 to 0.20095385405587618
# Saving model to ../ckpt/RCNN_0.20095385405587618.pt
# training epoch 2
# {
#     "dish_look": 0.2088283251805264,
#     "dish_portion": 0.17549325025960538,
#     "dish_recommendation": 0.22307351475095077,
#     "dish_taste": 0.17168621957625635,
#     "environment_cleaness": 0.19507236949097415,
#     "environment_decoration": 0.17106705846234815,
#     "environment_noise": 0.20612436816739158,
#     "environment_space": 0.19376505655138623,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.21715190828179212,
#     "location_traffic_convenience": 0.21969951788317077,
#     "others_overall_experience": 0.20089730807577266,
#     "others_willing_to_consume_again": 0.19204237496920423,
#     "price_cost_effective": 0.21621008021795066,
#     "price_discount": 0.19087461874536316,
#     "price_level": 0.16662221629550608,
#     "service_parking_convenience": 0.241788886593679,
#     "service_serving_speed": 0.22901687321602773,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.14232915255853879
# }
# epoch: 2 LR: 0.005, F1_score:0.20093425985453486
# F1-score did not improved from 0.20095385405587618 for 1 epochs
# Loading model from ../ckpt/RCNN_0.20095385405587618.pt
# training epoch 3
# {
#     "dish_look": 0.2734151325804002,
#     "dish_portion": 0.4003012946860758,
#     "dish_recommendation": 0.3149030266629851,
#     "dish_taste": 0.3523290599017127,
#     "environment_cleaness": 0.2600087474424274,
#     "environment_decoration": 0.29062928579251734,
#     "environment_noise": 0.31020125408757715,
#     "environment_space": 0.2837436045410514,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.21715190828179212,
#     "location_traffic_convenience": 0.2917161690053045,
#     "others_overall_experience": 0.4548678099725395,
#     "others_willing_to_consume_again": 0.5501117527822877,
#     "price_cost_effective": 0.31866902886593196,
#     "price_discount": 0.36360301103106674,
#     "price_level": 0.45470970033072283,
#     "service_parking_convenience": 0.241788886593679,
#     "service_serving_speed": 0.24590029115960252,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.3947268380015117
# }
# epoch: 3 LR: 0.0045000000000000005, F1_score:0.3237859449766719
# F1-score improved from 0.20095385405587618 to 0.3237859449766719
# Saving model to ../ckpt/RCNN_0.3237859449766719.pt
# training epoch 4
# {
#     "dish_look": 0.3063874520935996,
#     "dish_portion": 0.4616307988373023,
#     "dish_recommendation": 0.5119130063562173,
#     "dish_taste": 0.4731306273143648,
#     "environment_cleaness": 0.3876913489478254,
#     "environment_decoration": 0.3518544080484177,
#     "environment_noise": 0.2986912251802534,
#     "environment_space": 0.27601218000288924,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.21715190828179212,
#     "location_traffic_convenience": 0.18705385886606535,
#     "others_overall_experience": 0.4786472674348322,
#     "others_willing_to_consume_again": 0.5999334669696034,
#     "price_cost_effective": 0.5788412390654185,
#     "price_discount": 0.39256272761110905,
#     "price_level": 0.5846505997947373,
#     "service_parking_convenience": 0.241788886593679,
#     "service_serving_speed": 0.4069313687263344,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.47795056455651075
# }
# epoch: 4 LR: 0.0045000000000000005, F1_score:0.38448825162476025
# F1-score improved from 0.3237859449766719 to 0.38448825162476025
# Saving model to ../ckpt/RCNN_0.38448825162476025.pt
# training epoch 5
# {
#     "dish_look": 0.3244587390641746,
#     "dish_portion": 0.2229279244052754,
#     "dish_recommendation": 0.547177292823671,
#     "dish_taste": 0.4029548510440949,
#     "environment_cleaness": 0.41892414137131967,
#     "environment_decoration": 0.3584786625905382,
#     "environment_noise": 0.43688483583942195,
#     "environment_space": 0.3245927379624705,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.21715190828179212,
#     "location_traffic_convenience": 0.30818307947338075,
#     "others_overall_experience": 0.42304240824052874,
#     "others_willing_to_consume_again": 0.6002023411225079,
#     "price_cost_effective": 0.5419820298004712,
#     "price_discount": 0.24143702322840352,
#     "price_level": 0.5515015608639321,
#     "service_parking_convenience": 0.3140882331522154,
#     "service_serving_speed": 0.45927450746687365,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.48860066170168936
# }
# epoch: 5 LR: 0.0045000000000000005, F1_score:0.3819402518123507
# F1-score did not improved from 0.38448825162476025 for 1 epochs
# Loading model from ../ckpt/RCNN_0.38448825162476025.pt
# training epoch 6
# {
#     "dish_look": 0.29805521435989546,
#     "dish_portion": 0.3321529858367867,
#     "dish_recommendation": 0.33774146933917165,
#     "dish_taste": 0.4359066093658225,
#     "environment_cleaness": 0.4067378760918434,
#     "environment_decoration": 0.33037812508199327,
#     "environment_noise": 0.37018501985255364,
#     "environment_space": 0.32430459703010184,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.22088260736738027,
#     "location_traffic_convenience": 0.29821763474076046,
#     "others_overall_experience": 0.40581459734959874,
#     "others_willing_to_consume_again": 0.5900225287837937,
#     "price_cost_effective": 0.5587049299303573,
#     "price_discount": 0.3789873710077958,
#     "price_level": 0.6046894249294779,
#     "service_parking_convenience": 0.312959942493505,
#     "service_serving_speed": 0.45449074907232556,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.47246874246078685
# }
# epoch: 6 LR: 0.004050000000000001, F1_score:0.3794821261454101
# F1-score did not improved from 0.38448825162476025 for 2 epochs
# Loading model from ../ckpt/RCNN_0.38448825162476025.pt
# training epoch 7
# {
#     "dish_look": 0.3126736356592761,
#     "dish_portion": 0.4344981373434217,
#     "dish_recommendation": 0.5064291256600912,
#     "dish_taste": 0.5324372208167646,
#     "environment_cleaness": 0.471291376840892,
#     "environment_decoration": 0.32640196952845135,
#     "environment_noise": 0.432957194472493,
#     "environment_space": 0.3026804661090736,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.2219511234906311,
#     "location_traffic_convenience": 0.3089058858068934,
#     "others_overall_experience": 0.45368308758038794,
#     "others_willing_to_consume_again": 0.6185067318690064,
#     "price_cost_effective": 0.5051504289884947,
#     "price_discount": 0.39761976999470505,
#     "price_level": 0.5070021561104001,
#     "service_parking_convenience": 0.2947853674393719,
#     "service_serving_speed": 0.38701783402857026,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.5663750197582407
# }
# epoch: 7 LR: 0.0036450000000000007, F1_score:0.4018654314655709
# F1-score improved from 0.38448825162476025 to 0.4018654314655709
# Saving model to ../ckpt/RCNN_0.4018654314655709.pt
# training epoch 8
# {
#     "dish_look": 0.316883549006125,
#     "dish_portion": 0.4941899666474814,
#     "dish_recommendation": 0.5144854020988627,
#     "dish_taste": 0.5562640512320665,
#     "environment_cleaness": 0.34955538304259787,
#     "environment_decoration": 0.34251539616333915,
#     "environment_noise": 0.4370107570852388,
#     "environment_space": 0.33179058705664016,
#     "location_distance_from_business_district": 0.2460322222700455,
#     "location_easy_to_find": 0.22314187486292547,
#     "location_traffic_convenience": 0.29342910264784616,
#     "others_overall_experience": 0.5362668187583955,
#     "others_willing_to_consume_again": 0.6249075971768121,
#     "price_cost_effective": 0.5503905846351376,
#     "price_discount": 0.39275777827612524,
#     "price_level": 0.5769859114166412,
#     "service_parking_convenience": 0.3149818154457291,
#     "service_serving_speed": 0.4359886778547755,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.45168512618924717
# }
# epoch: 8 LR: 0.0036450000000000007, F1_score:0.4111826824536798
# F1-score improved from 0.4018654314655709 to 0.4111826824536798
# Saving model to ../ckpt/RCNN_0.4111826824536798.pt
# training epoch 9
# {
#     "dish_look": 0.2697891714533613,
#     "dish_portion": 0.42465771706637584,
#     "dish_recommendation": 0.5452690722983327,
#     "dish_taste": 0.2959820497839268,
#     "environment_cleaness": 0.3641957667645954,
#     "environment_decoration": 0.30877846751604393,
#     "environment_noise": 0.4366363201884063,
#     "environment_space": 0.3229171460366628,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.27424613579528617,
#     "location_traffic_convenience": 0.259847846042104,
#     "others_overall_experience": 0.491480474239103,
#     "others_willing_to_consume_again": 0.47373528369728474,
#     "price_cost_effective": 0.5039308725447633,
#     "price_discount": 0.35908265998924804,
#     "price_level": 0.5230306218755936,
#     "service_parking_convenience": 0.30162015674423526,
#     "service_serving_speed": 0.3868681794194349,
#     "service_wait_time": 0.24687907260435218,
#     "service_waiters_attitude": 0.48639503155047925
# }
# epoch: 9 LR: 0.0036450000000000007, F1_score:0.3748946548108139
# F1-score did not improved from 0.4111826824536798 for 1 epochs
# Loading model from ../ckpt/RCNN_0.4111826824536798.pt
# training epoch 10
# {
#     "dish_look": 0.31732845033792073,
#     "dish_portion": 0.4784713418487825,
#     "dish_recommendation": 0.5541766442080636,
#     "dish_taste": 0.3714709972500536,
#     "environment_cleaness": 0.1973496500114496,
#     "environment_decoration": 0.33987660490054644,
#     "environment_noise": 0.4125225232555962,
#     "environment_space": 0.30464658194777683,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.22222205191671904,
#     "location_traffic_convenience": 0.27592536840790816,
#     "others_overall_experience": 0.44842979525679605,
#     "others_willing_to_consume_again": 0.6111444463212831,
#     "price_cost_effective": 0.5850062719392592,
#     "price_discount": 0.3724351356015111,
#     "price_level": 0.6132142202041623,
#     "service_parking_convenience": 0.3148031236237267,
#     "service_serving_speed": 0.46575482359110426,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.5550559072594208
# }
# epoch: 10 LR: 0.003280500000000001, F1_score:0.3948388017848167
# F1-score did not improved from 0.4111826824536798 for 2 epochs
# Loading model from ../ckpt/RCNN_0.4111826824536798.pt
# training epoch 11
# {
#     "dish_look": 0.29210851423817735,
#     "dish_portion": 0.19284944557537237,
#     "dish_recommendation": 0.5519465436361313,
#     "dish_taste": 0.4616655822923805,
#     "environment_cleaness": 0.40352553374978856,
#     "environment_decoration": 0.3574532848630032,
#     "environment_noise": 0.48214677933157096,
#     "environment_space": 0.3250610051638336,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.221436853865227,
#     "location_traffic_convenience": 0.2653519008959319,
#     "others_overall_experience": 0.36625625099784287,
#     "others_willing_to_consume_again": 0.6041742506621357,
#     "price_cost_effective": 0.5314449603026165,
#     "price_discount": 0.2241503134632808,
#     "price_level": 0.56238265655232,
#     "service_parking_convenience": 0.3157583617067452,
#     "service_serving_speed": 0.4688036532702999,
#     "service_wait_time": 0.2486402637612048,
#     "service_waiters_attitude": 0.5605905117507131
# }
# epoch: 11 LR: 0.002952450000000001, F1_score:0.3829148858342632
# F1-score did not improved from 0.4111826824536798 for 3 epochs
# Loading model from ../ckpt/RCNN_0.4111826824536798.pt
# training epoch 12
# {
#     "dish_look": 0.28342899093153767,
#     "dish_portion": 0.5072099634973006,
#     "dish_recommendation": 0.47861721793723633,
#     "dish_taste": 0.552737586932462,
#     "environment_cleaness": 0.462313192222017,
#     "environment_decoration": 0.3525732150014244,
#     "environment_noise": 0.4389953378159186,
#     "environment_space": 0.32324879118077104,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.22439568314740158,
#     "location_traffic_convenience": 0.299770005274453,
#     "others_overall_experience": 0.47518934339619523,
#     "others_willing_to_consume_again": 0.6534453642082904,
#     "price_cost_effective": 0.5753724567086159,
#     "price_discount": 0.42294720124838725,
#     "price_level": 0.5893767902777451,
#     "service_parking_convenience": 0.3148031236237267,
#     "service_serving_speed": 0.46826552704519375,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.43919761599819274
# }
# epoch: 12 LR: 0.002657205000000001, F1_score:0.41594147521305613
# F1-score improved from 0.4111826824536798 to 0.41594147521305613
# Saving model to ../ckpt/RCNN_0.41594147521305613.pt
# training epoch 13
# {
#     "dish_look": 0.31199906493288015,
#     "dish_portion": 0.4303898380594956,
#     "dish_recommendation": 0.3487381095026687,
#     "dish_taste": 0.5448285634853123,
#     "environment_cleaness": 0.4711804247209606,
#     "environment_decoration": 0.3337578630193717,
#     "environment_noise": 0.4810236098490348,
#     "environment_space": 0.3118076311155852,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.2373534826499421,
#     "location_traffic_convenience": 0.18498417501175185,
#     "others_overall_experience": 0.5331490778034399,
#     "others_willing_to_consume_again": 0.5923199636092588,
#     "price_cost_effective": 0.476566289833933,
#     "price_discount": 0.33625298022881983,
#     "price_level": 0.5724939704688485,
#     "service_parking_convenience": 0.31528501890793204,
#     "service_serving_speed": 0.4585594331156229,
#     "service_wait_time": 0.24755899037423962,
#     "service_waiters_attitude": 0.4930829840315105
# }
# epoch: 13 LR: 0.002657205000000001, F1_score:0.3951941260663649
# F1-score did not improved from 0.41594147521305613 for 1 epochs
# Loading model from ../ckpt/RCNN_0.41594147521305613.pt
# training epoch 14
# {
#     "dish_look": 0.3222754003083763,
#     "dish_portion": 0.49123432698643416,
#     "dish_recommendation": 0.5150924838712863,
#     "dish_taste": 0.5537313485044856,
#     "environment_cleaness": 0.46869425482006205,
#     "environment_decoration": 0.3480285907021783,
#     "environment_noise": 0.44231717284237504,
#     "environment_space": 0.3690998126088408,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.22883604307724198,
#     "location_traffic_convenience": 0.30943299257404305,
#     "others_overall_experience": 0.47115220493209387,
#     "others_willing_to_consume_again": 0.6720328309366312,
#     "price_cost_effective": 0.5406395144188471,
#     "price_discount": 0.3156836302143943,
#     "price_level": 0.5759652340645849,
#     "service_parking_convenience": 0.315915191288325,
#     "service_serving_speed": 0.46027710293575474,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.5650562951006711
# }
# epoch: 14 LR: 0.002391484500000001, F1_score:0.4211203264000439
# F1-score improved from 0.41594147521305613 to 0.4211203264000439
# Saving model to ../ckpt/RCNN_0.4211203264000439.pt
# training epoch 15
# {
#     "dish_look": 0.34659368446419303,
#     "dish_portion": 0.42903069016529627,
#     "dish_recommendation": 0.4686564215218038,
#     "dish_taste": 0.4347770148445932,
#     "environment_cleaness": 0.4304929392617661,
#     "environment_decoration": 0.36132639999748617,
#     "environment_noise": 0.47598153601263143,
#     "environment_space": 0.33882912646026936,
#     "location_distance_from_business_district": 0.22736998231688732,
#     "location_easy_to_find": 0.2423066751320959,
#     "location_traffic_convenience": 0.26864874505027664,
#     "others_overall_experience": 0.4379972169971509,
#     "others_willing_to_consume_again": 0.61970604970886,
#     "price_cost_effective": 0.5758560247089171,
#     "price_discount": 0.4001540001305378,
#     "price_level": 0.5966445430238335,
#     "service_parking_convenience": 0.3177328640246995,
#     "service_serving_speed": 0.4078040795524312,
#     "service_wait_time": 0.2859130314559091,
#     "service_waiters_attitude": 0.4973331999901638
# }
# epoch: 15 LR: 0.002391484500000001, F1_score:0.4081577112409901
# F1-score did not improved from 0.4211203264000439 for 1 epochs
# Loading model from ../ckpt/RCNN_0.4211203264000439.pt
# training epoch 16
# {
#     "dish_look": 0.24274406494491624,
#     "dish_portion": 0.44938390992230537,
#     "dish_recommendation": 0.5593815739768242,
#     "dish_taste": 0.505629737677671,
#     "environment_cleaness": 0.41611127159152045,
#     "environment_decoration": 0.3778695638421017,
#     "environment_noise": 0.48559700144696627,
#     "environment_space": 0.30523312603167324,
#     "location_distance_from_business_district": 0.22254078650438386,
#     "location_easy_to_find": 0.22602662897016465,
#     "location_traffic_convenience": 0.2740271081252334,
#     "others_overall_experience": 0.4571819393393211,
#     "others_willing_to_consume_again": 0.6219122741551981,
#     "price_cost_effective": 0.5654399002409496,
#     "price_discount": 0.4121488797579088,
#     "price_level": 0.6003629104880103,
#     "service_parking_convenience": 0.3012172205737333,
#     "service_serving_speed": 0.4469439899195039,
#     "service_wait_time": 0.27023546548152316,
#     "service_waiters_attitude": 0.5550885740995983
# }
# epoch: 16 LR: 0.002152336050000001, F1_score:0.4147537963544753
# F1-score did not improved from 0.4211203264000439 for 2 epochs
# Loading model from ../ckpt/RCNN_0.4211203264000439.pt
# training epoch 17
# {
#     "dish_look": 0.3710205493559767,
#     "dish_portion": 0.4145093281129295,
#     "dish_recommendation": 0.5320888588670882,
#     "dish_taste": 0.494900165655886,
#     "environment_cleaness": 0.4640850137169452,
#     "environment_decoration": 0.3565959186853266,
#     "environment_noise": 0.45186002990823904,
#     "environment_space": 0.3336700387873126,
#     "location_distance_from_business_district": 0.22614468001570473,
#     "location_easy_to_find": 0.2237856482652118,
#     "location_traffic_convenience": 0.2701077159647861,
#     "others_overall_experience": 0.5411103551367776,
#     "others_willing_to_consume_again": 0.6505211246768002,
#     "price_cost_effective": 0.5818751512309902,
#     "price_discount": 0.41087130157641244,
#     "price_level": 0.5410260648274079,
#     "service_parking_convenience": 0.314999160296043,
#     "service_serving_speed": 0.47862767958241453,
#     "service_wait_time": 0.2602686973408669,
#     "service_waiters_attitude": 0.5428605228433293
# }
# epoch: 17 LR: 0.001937102445000001, F1_score:0.4230464002423225
# F1-score improved from 0.4211203264000439 to 0.4230464002423225
# Saving model to ../ckpt/RCNN_0.4230464002423225.pt
# training epoch 18
# {
#     "dish_look": 0.2212153441214602,
#     "dish_portion": 0.43579828555833944,
#     "dish_recommendation": 0.43989006012839027,
#     "dish_taste": 0.5551693549851321,
#     "environment_cleaness": 0.4777155380668668,
#     "environment_decoration": 0.3408838306419505,
#     "environment_noise": 0.4373059581260764,
#     "environment_space": 0.38733598709179984,
#     "location_distance_from_business_district": 0.2404334625744184,
#     "location_easy_to_find": 0.27695667944397695,
#     "location_traffic_convenience": 0.2654058111519216,
#     "others_overall_experience": 0.3248666790295981,
#     "others_willing_to_consume_again": 0.6537775871827729,
#     "price_cost_effective": 0.4862104065971104,
#     "price_discount": 0.4220591366561501,
#     "price_level": 0.5796579804280665,
#     "service_parking_convenience": 0.3297663914519664,
#     "service_serving_speed": 0.48262494670784734,
#     "service_wait_time": 0.2343910472075645,
#     "service_waiters_attitude": 0.603467801504444
# }
# epoch: 18 LR: 0.001937102445000001, F1_score:0.40974661443279264
# F1-score did not improved from 0.4230464002423225 for 1 epochs
# Loading model from ../ckpt/RCNN_0.4230464002423225.pt
# training epoch 19
# {
#     "dish_look": 0.29563106837417225,
#     "dish_portion": 0.4317948163284856,
#     "dish_recommendation": 0.5255495961102326,
#     "dish_taste": 0.4298072790881149,
#     "environment_cleaness": 0.48479735616799424,
#     "environment_decoration": 0.23923456313131702,
#     "environment_noise": 0.4498249600429104,
#     "environment_space": 0.3898923609626101,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.23172718430580874,
#     "location_traffic_convenience": 0.3080279958566758,
#     "others_overall_experience": 0.4881898321177819,
#     "others_willing_to_consume_again": 0.6376406447847806,
#     "price_cost_effective": 0.5396101914635256,
#     "price_discount": 0.39736279817045134,
#     "price_level": 0.6131254273241687,
#     "service_parking_convenience": 0.3162120265467929,
#     "service_serving_speed": 0.4663725655435357,
#     "service_wait_time": 0.2953300383024048,
#     "service_waiters_attitude": 0.2389775308383769
# }
# epoch: 19 LR: 0.001743392200500001, F1_score:0.40008296430334145
# F1-score did not improved from 0.4230464002423225 for 2 epochs
# Loading model from ../ckpt/RCNN_0.4230464002423225.pt
# training epoch 20
# {
#     "dish_look": 0.31063043680847413,
#     "dish_portion": 0.4193047825188082,
#     "dish_recommendation": 0.5397753450125831,
#     "dish_taste": 0.4814360183006552,
#     "environment_cleaness": 0.4732085949827273,
#     "environment_decoration": 0.3545988614919442,
#     "environment_noise": 0.4908218435089141,
#     "environment_space": 0.3185089392869349,
#     "location_distance_from_business_district": 0.2316617962261729,
#     "location_easy_to_find": 0.2469855354994776,
#     "location_traffic_convenience": 0.3010816321555191,
#     "others_overall_experience": 0.4725172967203959,
#     "others_willing_to_consume_again": 0.6569113708659824,
#     "price_cost_effective": 0.5241653814307756,
#     "price_discount": 0.4226390357147949,
#     "price_level": 0.5736378845122092,
#     "service_parking_convenience": 0.3157405529552203,
#     "service_serving_speed": 0.4865991307027254,
#     "service_wait_time": 0.2666518769153243,
#     "service_waiters_attitude": 0.5673074446591156
# }
# epoch: 20 LR: 0.001569052980450001, F1_score:0.42270918801343776
# F1-score did not improved from 0.4230464002423225 for 3 epochs
# Loading model from ../ckpt/RCNN_0.4230464002423225.pt
# training epoch 21
# {
#     "dish_look": 0.32180330588003997,
#     "dish_portion": 0.4933654593129456,
#     "dish_recommendation": 0.5621835768617331,
#     "dish_taste": 0.47412532730942003,
#     "environment_cleaness": 0.4726896502209788,
#     "environment_decoration": 0.37096717160560444,
#     "environment_noise": 0.48283824142445647,
#     "environment_space": 0.3612211620276027,
#     "location_distance_from_business_district": 0.24621550150668142,
#     "location_easy_to_find": 0.22694047144113108,
#     "location_traffic_convenience": 0.3004254575393376,
#     "others_overall_experience": 0.5192992532802855,
#     "others_willing_to_consume_again": 0.6319794957819536,
#     "price_cost_effective": 0.4968411100739868,
#     "price_discount": 0.33541392796088865,
#     "price_level": 0.6059665435790766,
#     "service_parking_convenience": 0.31867851938294534,
#     "service_serving_speed": 0.4718895947004601,
#     "service_wait_time": 0.26101559641552063,
#     "service_waiters_attitude": 0.5780876284152285
# }
# epoch: 21 LR: 0.0014121476824050009, F1_score:0.4265973497360139
# F1-score improved from 0.4230464002423225 to 0.4265973497360139
# Saving model to ../ckpt/RCNN_0.4265973497360139.pt
# training epoch 22
# {
#     "dish_look": 0.33129154819576734,
#     "dish_portion": 0.4630570708170385,
#     "dish_recommendation": 0.5323412179221113,
#     "dish_taste": 0.5492229739939788,
#     "environment_cleaness": 0.4750321854843791,
#     "environment_decoration": 0.3941542098516302,
#     "environment_noise": 0.4258576428829456,
#     "environment_space": 0.3421410870267534,
#     "location_distance_from_business_district": 0.26522029035020406,
#     "location_easy_to_find": 0.22201349054511277,
#     "location_traffic_convenience": 0.2920311112307237,
#     "others_overall_experience": 0.530654258835589,
#     "others_willing_to_consume_again": 0.6426576313197931,
#     "price_cost_effective": 0.6108356958973556,
#     "price_discount": 0.4169871323887918,
#     "price_level": 0.5761613457573425,
#     "service_parking_convenience": 0.29132264488674087,
#     "service_serving_speed": 0.46878596125077154,
#     "service_wait_time": 0.2663550877787363,
#     "service_waiters_attitude": 0.5834214303088343
# }
# epoch: 22 LR: 0.0014121476824050009, F1_score:0.4339772008362299
# F1-score improved from 0.4265973497360139 to 0.4339772008362299
# Saving model to ../ckpt/RCNN_0.4339772008362299.pt
# training epoch 23
# {
#     "dish_look": 0.34581295976059556,
#     "dish_portion": 0.46338869879482425,
#     "dish_recommendation": 0.5367590625900939,
#     "dish_taste": 0.5168344512168217,
#     "environment_cleaness": 0.47614902586281904,
#     "environment_decoration": 0.3566266152300048,
#     "environment_noise": 0.4825700634211506,
#     "environment_space": 0.4060889337461078,
#     "location_distance_from_business_district": 0.22678952654111817,
#     "location_easy_to_find": 0.27698414325659115,
#     "location_traffic_convenience": 0.3141520264423521,
#     "others_overall_experience": 0.4961790005610545,
#     "others_willing_to_consume_again": 0.6282881220089831,
#     "price_cost_effective": 0.5578239707441154,
#     "price_discount": 0.43245376237117145,
#     "price_level": 0.6008573181140442,
#     "service_parking_convenience": 0.33073999434923795,
#     "service_serving_speed": 0.4854506377347172,
#     "service_wait_time": 0.30114879479221335,
#     "service_waiters_attitude": 0.51534194649731
# }
# epoch: 23 LR: 0.0014121476824050009, F1_score:0.43752195270176636
# F1-score improved from 0.4339772008362299 to 0.43752195270176636
# Saving model to ../ckpt/RCNN_0.43752195270176636.pt
# training epoch 24
# {
#     "dish_look": 0.3016881613834176,
#     "dish_portion": 0.46934580192818204,
#     "dish_recommendation": 0.25544745064710883,
#     "dish_taste": 0.40656610312556385,
#     "environment_cleaness": 0.4403568406131383,
#     "environment_decoration": 0.25503823091176064,
#     "environment_noise": 0.47626112826369826,
#     "environment_space": 0.3590551741127311,
#     "location_distance_from_business_district": 0.2741211325535811,
#     "location_easy_to_find": 0.2662315153551033,
#     "location_traffic_convenience": 0.30194240020369445,
#     "others_overall_experience": 0.5114837995562582,
#     "others_willing_to_consume_again": 0.6648246018619319,
#     "price_cost_effective": 0.6050887822069582,
#     "price_discount": 0.41121650500363094,
#     "price_level": 0.544048788972598,
#     "service_parking_convenience": 0.3412016479239224,
#     "service_serving_speed": 0.47630480086719645,
#     "service_wait_time": 0.2648195861295186,
#     "service_waiters_attitude": 0.5184645017609512
# }
# epoch: 24 LR: 0.0014121476824050009, F1_score:0.4071753476690473
# F1-score did not improved from 0.43752195270176636 for 1 epochs
# Loading model from ../ckpt/RCNN_0.43752195270176636.pt
# training epoch 25
# {
#     "dish_look": 0.36247094124675766,
#     "dish_portion": 0.5061450382790925,
#     "dish_recommendation": 0.5244351518291239,
#     "dish_taste": 0.5396824838326724,
#     "environment_cleaness": 0.4819031005270876,
#     "environment_decoration": 0.40437548593729555,
#     "environment_noise": 0.49012206159116495,
#     "environment_space": 0.3758059863655825,
#     "location_distance_from_business_district": 0.23482344010125733,
#     "location_easy_to_find": 0.27862959516914587,
#     "location_traffic_convenience": 0.3088579768090566,
#     "others_overall_experience": 0.5012161399642894,
#     "others_willing_to_consume_again": 0.6435127089618221,
#     "price_cost_effective": 0.5748569748141484,
#     "price_discount": 0.39160739896263774,
#     "price_level": 0.6121570498336726,
#     "service_parking_convenience": 0.35590610895135516,
#     "service_serving_speed": 0.4853292868589941,
#     "service_wait_time": 0.2755847068962902,
#     "service_waiters_attitude": 0.6064250131903723
# }
# epoch: 25 LR: 0.0012709329141645008, F1_score:0.447692332506091
# F1-score improved from 0.43752195270176636 to 0.447692332506091
# Saving model to ../ckpt/RCNN_0.447692332506091.pt
# training epoch 26
# {
#     "dish_look": 0.3763402945047387,
#     "dish_portion": 0.4501088411765328,
#     "dish_recommendation": 0.5035948492975724,
#     "dish_taste": 0.5010445675823608,
#     "environment_cleaness": 0.4700713845178711,
#     "environment_decoration": 0.37108483559411487,
#     "environment_noise": 0.4739929686949402,
#     "environment_space": 0.37947999824867196,
#     "location_distance_from_business_district": 0.22943052978767264,
#     "location_easy_to_find": 0.24571859513120742,
#     "location_traffic_convenience": 0.30130274787080347,
#     "others_overall_experience": 0.502701736288572,
#     "others_willing_to_consume_again": 0.6227021044005727,
#     "price_cost_effective": 0.6041292301656256,
#     "price_discount": 0.4128769060238929,
#     "price_level": 0.49207367889661235,
#     "service_parking_convenience": 0.3592275381819185,
#     "service_serving_speed": 0.5062385742533639,
#     "service_wait_time": 0.2542980593318191,
#     "service_waiters_attitude": 0.5931154789720567
# }
# epoch: 26 LR: 0.0012709329141645008, F1_score:0.432476645946046
# F1-score did not improved from 0.447692332506091 for 1 epochs
# Loading model from ../ckpt/RCNN_0.447692332506091.pt
# training epoch 27
# {
#     "dish_look": 0.3531254953822628,
#     "dish_portion": 0.5056609531535765,
#     "dish_recommendation": 0.5190739738751444,
#     "dish_taste": 0.5236819330228424,
#     "environment_cleaness": 0.4743283881458997,
#     "environment_decoration": 0.3675078626650831,
#     "environment_noise": 0.45091886144640425,
#     "environment_space": 0.3795918994983944,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.22299215263018038,
#     "location_traffic_convenience": 0.26910773196992893,
#     "others_overall_experience": 0.5019131002134272,
#     "others_willing_to_consume_again": 0.6253894777126381,
#     "price_cost_effective": 0.5811935742119925,
#     "price_discount": 0.43105175850495736,
#     "price_level": 0.5902114698103971,
#     "service_parking_convenience": 0.3279314634120676,
#     "service_serving_speed": 0.4997701326139242,
#     "service_wait_time": 0.25145394543475874,
#     "service_waiters_attitude": 0.5569114812344047
# }
# epoch: 27 LR: 0.0011438396227480508, F1_score:0.4327183352772487
# F1-score did not improved from 0.447692332506091 for 2 epochs
# Loading model from ../ckpt/RCNN_0.447692332506091.pt
# training epoch 28
# {
#     "dish_look": 0.30929737532040597,
#     "dish_portion": 0.31262333382286983,
#     "dish_recommendation": 0.5175571926166174,
#     "dish_taste": 0.5430275811131222,
#     "environment_cleaness": 0.45820978137877677,
#     "environment_decoration": 0.37697927315908086,
#     "environment_noise": 0.4771300017914742,
#     "environment_space": 0.36224451193509083,
#     "location_distance_from_business_district": 0.225930964533438,
#     "location_easy_to_find": 0.26911446442120884,
#     "location_traffic_convenience": 0.30255734587997773,
#     "others_overall_experience": 0.5236473064374778,
#     "others_willing_to_consume_again": 0.6423219871654615,
#     "price_cost_effective": 0.6066313123261128,
#     "price_discount": 0.41333769853796143,
#     "price_level": 0.6040600322322353,
#     "service_parking_convenience": 0.32376961026969,
#     "service_serving_speed": 0.4774624094162162,
#     "service_wait_time": 0.33416816072849953,
#     "service_waiters_attitude": 0.5890733218927755
# }
# epoch: 28 LR: 0.0010294556604732458, F1_score:0.43345718324892457
# F1-score did not improved from 0.447692332506091 for 3 epochs
# Loading model from ../ckpt/RCNN_0.447692332506091.pt
# training epoch 29
# {
#     "dish_look": 0.36466971265558557,
#     "dish_portion": 0.40158470746969427,
#     "dish_recommendation": 0.5515060159047946,
#     "dish_taste": 0.5324687080512512,
#     "environment_cleaness": 0.4016113313748937,
#     "environment_decoration": 0.37374442458595325,
#     "environment_noise": 0.4650059612618953,
#     "environment_space": 0.37272302774791244,
#     "location_distance_from_business_district": 0.23069897597976582,
#     "location_easy_to_find": 0.22926593312059865,
#     "location_traffic_convenience": 0.2854759546716253,
#     "others_overall_experience": 0.480955221648835,
#     "others_willing_to_consume_again": 0.6719771807617085,
#     "price_cost_effective": 0.5881215366759387,
#     "price_discount": 0.4103274496224682,
#     "price_level": 0.5889963598631949,
#     "service_parking_convenience": 0.34923855261682885,
#     "service_serving_speed": 0.4756764717096099,
#     "service_wait_time": 0.32708802446824436,
#     "service_waiters_attitude": 0.5756414723043177
# }
# epoch: 29 LR: 0.0009265100944259213, F1_score:0.43383885112475573
# F1-score did not improved from 0.447692332506091 for 4 epochs
# Loading model from ../ckpt/RCNN_0.447692332506091.pt
# training epoch 30
# {
#     "dish_look": 0.3365369059965698,
#     "dish_portion": 0.5232925431014459,
#     "dish_recommendation": 0.5369688013139204,
#     "dish_taste": 0.5512088981835839,
#     "environment_cleaness": 0.4350684658846358,
#     "environment_decoration": 0.36493921053410505,
#     "environment_noise": 0.456307617518093,
#     "environment_space": 0.37385223945872725,
#     "location_distance_from_business_district": 0.22304853294890134,
#     "location_easy_to_find": 0.23593446181982275,
#     "location_traffic_convenience": 0.32897340951625764,
#     "others_overall_experience": 0.5144972152128194,
#     "others_willing_to_consume_again": 0.659907954563075,
#     "price_cost_effective": 0.5856553625218002,
#     "price_discount": 0.41798048479597993,
#     "price_level": 0.5943770965998633,
#     "service_parking_convenience": 0.34521057078762335,
#     "service_serving_speed": 0.4808996830513843,
#     "service_wait_time": 0.3058049324796112,
#     "service_waiters_attitude": 0.5877449005975306
# }
# epoch: 30 LR: 0.0008338590849833291, F1_score:0.4429104643442875
# F1-score did not improved from 0.447692332506091 for 5 epochs
# Loading model from ../ckpt/RCNN_0.447692332506091.pt
# training epoch 31
# {
#     "dish_look": 0.32598633588065906,
#     "dish_portion": 0.5078761069416341,
#     "dish_recommendation": 0.5171676344877578,
#     "dish_taste": 0.566799038886458,
#     "environment_cleaness": 0.47462590812980754,
#     "environment_decoration": 0.3898689896128791,
#     "environment_noise": 0.48628108023702205,
#     "environment_space": 0.3965298137063109,
#     "location_distance_from_business_district": 0.23893989212354072,
#     "location_easy_to_find": 0.2343371824273445,
#     "location_traffic_convenience": 0.292829493576988,
#     "others_overall_experience": 0.5022053099717418,
#     "others_willing_to_consume_again": 0.6617395576469525,
#     "price_cost_effective": 0.5797982037685891,
#     "price_discount": 0.42580838963468814,
#     "price_level": 0.5869288611817478,
#     "service_parking_convenience": 0.3578010714268181,
#     "service_serving_speed": 0.493017478705863,
#     "service_wait_time": 0.3118358411934248,
#     "service_waiters_attitude": 0.576390522785655
# }
# epoch: 31 LR: 0.0007504731764849962, F1_score:0.4463383356162941
# F1-score did not improved from 0.447692332506091 for 6 epochs
# Loading model from ../ckpt/RCNN_0.447692332506091.pt
# training epoch 32
# {
#     "dish_look": 0.33837322981734264,
#     "dish_portion": 0.49651793670159394,
#     "dish_recommendation": 0.5374719760757543,
#     "dish_taste": 0.5321384856962696,
#     "environment_cleaness": 0.46202553499333265,
#     "environment_decoration": 0.3865261725419796,
#     "environment_noise": 0.48108047531728215,
#     "environment_space": 0.36940111305622764,
#     "location_distance_from_business_district": 0.2243050351041311,
#     "location_easy_to_find": 0.23798026702685118,
#     "location_traffic_convenience": 0.28958044222954044,
#     "others_overall_experience": 0.5186008070780455,
#     "others_willing_to_consume_again": 0.6272548757015249,
#     "price_cost_effective": 0.61476136654472,
#     "price_discount": 0.4145530398730281,
#     "price_level": 0.6004028492926995,
#     "service_parking_convenience": 0.35711255449514356,
#     "service_serving_speed": 0.5031976086759816,
#     "service_wait_time": 0.3185706041307957,
#     "service_waiters_attitude": 0.6032603916145509
# }
# epoch: 32 LR: 0.0006754258588364966, F1_score:0.4456557382983398
# F1-score did not improved from 0.447692332506091 for 7 epochs
# Loading model from ../ckpt/RCNN_0.447692332506091.pt
# training epoch 33
# {
#     "dish_look": 0.3716750407151427,
#     "dish_portion": 0.5001624867529436,
#     "dish_recommendation": 0.5540989036646767,
#     "dish_taste": 0.5478876116668356,
#     "environment_cleaness": 0.4737097319268073,
#     "environment_decoration": 0.4037684096751677,
#     "environment_noise": 0.48517377740708895,
#     "environment_space": 0.3736566806555832,
#     "location_distance_from_business_district": 0.22255105060668837,
#     "location_easy_to_find": 0.22240538004002985,
#     "location_traffic_convenience": 0.28040224396201263,
#     "others_overall_experience": 0.5126062457384225,
#     "others_willing_to_consume_again": 0.6649846412841474,
#     "price_cost_effective": 0.6152066056041172,
#     "price_discount": 0.4070319338130304,
#     "price_level": 0.6166867792762235,
#     "service_parking_convenience": 0.35316809410473127,
#     "service_serving_speed": 0.49453646751810215,
#     "service_wait_time": 0.2779276928056709,
#     "service_waiters_attitude": 0.5769414067795785
# }
# epoch: 33 LR: 0.000607883272952847, F1_score:0.44772905919985007
# F1-score improved from 0.447692332506091 to 0.44772905919985007
# Saving model to ../ckpt/RCNN_0.44772905919985007.pt
# training epoch 34
# {
#     "dish_look": 0.37217410668428735,
#     "dish_portion": 0.5108774943927276,
#     "dish_recommendation": 0.559924728212424,
#     "dish_taste": 0.560046890430578,
#     "environment_cleaness": 0.4771653413643836,
#     "environment_decoration": 0.3972078467785043,
#     "environment_noise": 0.4851432645700882,
#     "environment_space": 0.37520460128977473,
#     "location_distance_from_business_district": 0.24263357135496888,
#     "location_easy_to_find": 0.23730685194360046,
#     "location_traffic_convenience": 0.28809699845576,
#     "others_overall_experience": 0.5256965816141717,
#     "others_willing_to_consume_again": 0.6415225350586049,
#     "price_cost_effective": 0.5726034893156647,
#     "price_discount": 0.40612175680667484,
#     "price_level": 0.5972431292216901,
#     "service_parking_convenience": 0.3445489474838217,
#     "service_serving_speed": 0.5003647931301971,
#     "service_wait_time": 0.27192621507747455,
#     "service_waiters_attitude": 0.5669687394618991
# }
# epoch: 34 LR: 0.000607883272952847, F1_score:0.44663889413236485
# F1-score did not improved from 0.44772905919985007 for 1 epochs
# Loading model from ../ckpt/RCNN_0.44772905919985007.pt
# training epoch 35
# {
#     "dish_look": 0.38131537585477954,
#     "dish_portion": 0.503992463484441,
#     "dish_recommendation": 0.555817229446975,
#     "dish_taste": 0.4724856792187879,
#     "environment_cleaness": 0.4626838131212344,
#     "environment_decoration": 0.3885271256713808,
#     "environment_noise": 0.47744145676690497,
#     "environment_space": 0.3639561047717099,
#     "location_distance_from_business_district": 0.24219944355661666,
#     "location_easy_to_find": 0.25012163559094913,
#     "location_traffic_convenience": 0.2952022401670892,
#     "others_overall_experience": 0.5326103335790012,
#     "others_willing_to_consume_again": 0.6643573642141939,
#     "price_cost_effective": 0.6126638261054813,
#     "price_discount": 0.4238701945727203,
#     "price_level": 0.6048904452984621,
#     "service_parking_convenience": 0.3444410588662946,
#     "service_serving_speed": 0.4884726880089474,
#     "service_wait_time": 0.28537140243926384,
#     "service_waiters_attitude": 0.5522753321946486
# }
# epoch: 35 LR: 0.0005470949456575623, F1_score:0.44513476064649404
# F1-score did not improved from 0.44772905919985007 for 2 epochs
# Loading model from ../ckpt/RCNN_0.44772905919985007.pt
# training epoch 36
# {
#     "dish_look": 0.36618766109311846,
#     "dish_portion": 0.5145561200701898,
#     "dish_recommendation": 0.5579399971960476,
#     "dish_taste": 0.5415849276934579,
#     "environment_cleaness": 0.47518141621515964,
#     "environment_decoration": 0.387274452044407,
#     "environment_noise": 0.4909763220459553,
#     "environment_space": 0.3802027583158073,
#     "location_distance_from_business_district": 0.22361712418366267,
#     "location_easy_to_find": 0.23825304645371198,
#     "location_traffic_convenience": 0.3082826230362736,
#     "others_overall_experience": 0.5318780560122187,
#     "others_willing_to_consume_again": 0.6715283076922727,
#     "price_cost_effective": 0.5738703897579833,
#     "price_discount": 0.4358843591454745,
#     "price_level": 0.6185763239587089,
#     "service_parking_convenience": 0.3518183348124731,
#     "service_serving_speed": 0.4963127719324303,
#     "service_wait_time": 0.3101844089199512,
#     "service_waiters_attitude": 0.5931200589100523
# }
# epoch: 36 LR: 0.0004923854510918061, F1_score:0.4533614729744678
# F1-score improved from 0.44772905919985007 to 0.4533614729744678
# Saving model to ../ckpt/RCNN_0.4533614729744678.pt
# training epoch 37
# {
#     "dish_look": 0.3730348528412297,
#     "dish_portion": 0.522359289002135,
#     "dish_recommendation": 0.553647261459456,
#     "dish_taste": 0.5554429627542486,
#     "environment_cleaness": 0.48293293820389094,
#     "environment_decoration": 0.4055802670360765,
#     "environment_noise": 0.4821906647998853,
#     "environment_space": 0.3857475906649271,
#     "location_distance_from_business_district": 0.2314147293602771,
#     "location_easy_to_find": 0.2663365766181398,
#     "location_traffic_convenience": 0.322079675749984,
#     "others_overall_experience": 0.5256581800074818,
#     "others_willing_to_consume_again": 0.66638467354207,
#     "price_cost_effective": 0.5967059479151173,
#     "price_discount": 0.41948333661735043,
#     "price_level": 0.6124052165025985,
#     "service_parking_convenience": 0.35132079091755264,
#     "service_serving_speed": 0.4749326426522092,
#     "service_wait_time": 0.3158933478172834,
#     "service_waiters_attitude": 0.5799685303450022
# }
# epoch: 37 LR: 0.0004923854510918061, F1_score:0.4561759737403458
# F1-score improved from 0.4533614729744678 to 0.4561759737403458
# Saving model to ../ckpt/RCNN_0.4561759737403458.pt
# training epoch 38
# {
#     "dish_look": 0.3379036759964968,
#     "dish_portion": 0.5002162372971026,
#     "dish_recommendation": 0.547386282632145,
#     "dish_taste": 0.5343432938351691,
#     "environment_cleaness": 0.4722761736920594,
#     "environment_decoration": 0.3947229851287683,
#     "environment_noise": 0.48609117312237626,
#     "environment_space": 0.3802750159887491,
#     "location_distance_from_business_district": 0.24421722925404277,
#     "location_easy_to_find": 0.24977103310637583,
#     "location_traffic_convenience": 0.3312684217902404,
#     "others_overall_experience": 0.5127979537597879,
#     "others_willing_to_consume_again": 0.6733323625285523,
#     "price_cost_effective": 0.5892095058972925,
#     "price_discount": 0.4280330723650369,
#     "price_level": 0.6119027265380986,
#     "service_parking_convenience": 0.35491879712341823,
#     "service_serving_speed": 0.4853364062987675,
#     "service_wait_time": 0.2806865746092108,
#     "service_waiters_attitude": 0.5798402309789576
# }
# epoch: 38 LR: 0.0004923854510918061, F1_score:0.44972645759713237
# F1-score did not improved from 0.4561759737403458 for 1 epochs
# Loading model from ../ckpt/RCNN_0.4561759737403458.pt
# training epoch 39
# {
#     "dish_look": 0.3654013477742105,
#     "dish_portion": 0.48844325651122295,
#     "dish_recommendation": 0.559312342914068,
#     "dish_taste": 0.5415464159456991,
#     "environment_cleaness": 0.48525034745362516,
#     "environment_decoration": 0.376197512369861,
#     "environment_noise": 0.47823641063667355,
#     "environment_space": 0.3936867728575304,
#     "location_distance_from_business_district": 0.22816841573138488,
#     "location_easy_to_find": 0.24591252284064197,
#     "location_traffic_convenience": 0.2964970964156607,
#     "others_overall_experience": 0.5270100403448224,
#     "others_willing_to_consume_again": 0.6714922084948144,
#     "price_cost_effective": 0.5842873491682911,
#     "price_discount": 0.4237735139075277,
#     "price_level": 0.6059989723252592,
#     "service_parking_convenience": 0.3506990933824461,
#     "service_serving_speed": 0.4982255250615045,
#     "service_wait_time": 0.31289669581060825,
#     "service_waiters_attitude": 0.5781430965468205
# }
# epoch: 39 LR: 0.00044314690598262546, F1_score:0.45055894682463365
# F1-score did not improved from 0.4561759737403458 for 2 epochs
# Loading model from ../ckpt/RCNN_0.4561759737403458.pt
# training epoch 40
# {
#     "dish_look": 0.3499218659228582,
#     "dish_portion": 0.5140682089691336,
#     "dish_recommendation": 0.5484297862216009,
#     "dish_taste": 0.5676759030785639,
#     "environment_cleaness": 0.48479625840221774,
#     "environment_decoration": 0.41106291473255996,
#     "environment_noise": 0.4786461515691812,
#     "environment_space": 0.38648293827574376,
#     "location_distance_from_business_district": 0.22558176318229664,
#     "location_easy_to_find": 0.23649968096333787,
#     "location_traffic_convenience": 0.3164063252788732,
#     "others_overall_experience": 0.5275676478124243,
#     "others_willing_to_consume_again": 0.6527645727303946,
#     "price_cost_effective": 0.61735394604604,
#     "price_discount": 0.42596092416873454,
#     "price_level": 0.6184686479532113,
#     "service_parking_convenience": 0.34934690867200324,
#     "service_serving_speed": 0.4992085795460184,
# ...
#     "location_traffic_convenience": 0.3208444026986269,
#     "others_overall_experience": 0.5317757751157551,
#     "others_willing_to_consume_again": 0.6710650768893609,
#     "price_cost_effective": 0.6099857333029042,
#     "price_discount": 0.4305723233583784,
#     "price_level": 0.6177994642806685,
#     "service_parking_convenience": 0.36263164268540526,
#     "service_serving_speed": 0.4918964571795754,
#     "service_wait_time": 0.3126609915647479,
#     "service_waiters_attitude": 0.6019149510972853
# }
# epoch: 54 LR: 0.00011264199772469603, F1_score:0.4580920642153073
# F1-score did not improved from 0.4596552201619102 for 8 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 55
# {
#     "dish_look": 0.3653553556124847,
#     "dish_portion": 0.5092120397126122,
#     "dish_recommendation": 0.5591930671599723,
#     "dish_taste": 0.5386382452556873,
#     "environment_cleaness": 0.48153793330121203,
#     "environment_decoration": 0.3941471979983799,
#     "environment_noise": 0.4782045985831779,
#     "environment_space": 0.38808373368265753,
#     "location_distance_from_business_district": 0.2308360498660358,
#     "location_easy_to_find": 0.24565493197610289,
#     "location_traffic_convenience": 0.31926724587182814,
#     "others_overall_experience": 0.5340250005578564,
#     "others_willing_to_consume_again": 0.6717704159258218,
#     "price_cost_effective": 0.6083668430411132,
#     "price_discount": 0.43064236404829553,
#     "price_level": 0.6173682699249801,
#     "service_parking_convenience": 0.3565701125497026,
#     "service_serving_speed": 0.49563419932539843,
#     "service_wait_time": 0.3081577990170525,
#     "service_waiters_attitude": 0.60241795769027
# }
# epoch: 55 LR: 0.00010137779795222643, F1_score:0.45675416805503205
# F1-score did not improved from 0.4596552201619102 for 9 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 56
# {
#     "dish_look": 0.3677905706397301,
#     "dish_portion": 0.5111229632333757,
#     "dish_recommendation": 0.5619923230502897,
#     "dish_taste": 0.5446828285264745,
#     "environment_cleaness": 0.4833224095315442,
#     "environment_decoration": 0.39851581681830134,
#     "environment_noise": 0.48567249463734474,
#     "environment_space": 0.3885020642117754,
#     "location_distance_from_business_district": 0.232177712244292,
#     "location_easy_to_find": 0.2503993209995593,
#     "location_traffic_convenience": 0.31627292438991716,
#     "others_overall_experience": 0.5341700474795387,
#     "others_willing_to_consume_again": 0.6685143792602881,
#     "price_cost_effective": 0.6148668306133513,
#     "price_discount": 0.43056838946423076,
#     "price_level": 0.6179051201363757,
#     "service_parking_convenience": 0.35565153840411623,
#     "service_serving_speed": 0.49741728724532847,
#     "service_wait_time": 0.31792524839429337,
#     "service_waiters_attitude": 0.6001110281534564
# }
# epoch: 56 LR: 9.124001815700379e-05, F1_score:0.4588790648716792
# F1-score did not improved from 0.4596552201619102 for 10 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 57
# {
#     "dish_look": 0.3670756811874785,
#     "dish_portion": 0.510733564805329,
#     "dish_recommendation": 0.5503274742476665,
#     "dish_taste": 0.5476605372452522,
#     "environment_cleaness": 0.4851838455032494,
#     "environment_decoration": 0.39990004055240447,
#     "environment_noise": 0.4850583342685929,
#     "environment_space": 0.3945153159267014,
#     "location_distance_from_business_district": 0.2314950968710195,
#     "location_easy_to_find": 0.2454853773980822,
#     "location_traffic_convenience": 0.3242518599722576,
#     "others_overall_experience": 0.5311488097835031,
#     "others_willing_to_consume_again": 0.6706521777766274,
#     "price_cost_effective": 0.6107165557665161,
#     "price_discount": 0.43174643161673076,
#     "price_level": 0.6167939192530889,
#     "service_parking_convenience": 0.36223652053808536,
#     "service_serving_speed": 0.49245136454071714,
#     "service_wait_time": 0.29828767441168097,
#     "service_waiters_attitude": 0.6032815354824019
# }
# epoch: 57 LR: 8.211601634130342e-05, F1_score:0.4579501058573692
# F1-score did not improved from 0.4596552201619102 for 11 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 58
# {
#     "dish_look": 0.3634359219813514,
#     "dish_portion": 0.5169908829728023,
#     "dish_recommendation": 0.5538401511623793,
#     "dish_taste": 0.5475475121925574,
#     "environment_cleaness": 0.4815561795321376,
#     "environment_decoration": 0.40042404949919735,
#     "environment_noise": 0.48472252239609365,
#     "environment_space": 0.3909467361051664,
#     "location_distance_from_business_district": 0.23206876153789,
#     "location_easy_to_find": 0.2463832095070174,
#     "location_traffic_convenience": 0.3197561929728592,
#     "others_overall_experience": 0.5321632640688883,
#     "others_willing_to_consume_again": 0.6711713979039491,
#     "price_cost_effective": 0.6187003855823991,
#     "price_discount": 0.42837062312014973,
#     "price_level": 0.6182082148762158,
#     "service_parking_convenience": 0.35635341900475526,
#     "service_serving_speed": 0.4933380417355698,
#     "service_wait_time": 0.30801426600967663,
#     "service_waiters_attitude": 0.6000144617095411
# }
# epoch: 58 LR: 7.390441470717308e-05, F1_score:0.4582003096935298
# F1-score did not improved from 0.4596552201619102 for 12 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 59
# {
#     "dish_look": 0.37377274711898284,
#     "dish_portion": 0.511959520538575,
#     "dish_recommendation": 0.560329120830034,
#     "dish_taste": 0.5494810096883991,
#     "environment_cleaness": 0.48235764218501637,
#     "environment_decoration": 0.399606480178353,
#     "environment_noise": 0.4855130769869499,
#     "environment_space": 0.392832824162265,
#     "location_distance_from_business_district": 0.2315920266821364,
#     "location_easy_to_find": 0.24783691806651945,
#     "location_traffic_convenience": 0.3241379575746914,
#     "others_overall_experience": 0.5323764697381389,
#     "others_willing_to_consume_again": 0.6739526346378156,
#     "price_cost_effective": 0.6158125683631956,
#     "price_discount": 0.4294490203575513,
#     "price_level": 0.6195515375386287,
#     "service_parking_convenience": 0.358561362351006,
#     "service_serving_speed": 0.49330991706460753,
#     "service_wait_time": 0.30696999972618666,
#     "service_waiters_attitude": 0.5999215392409415
# }
# epoch: 59 LR: 6.651397323645577e-05, F1_score:0.45946621865149967
# F1-score did not improved from 0.4596552201619102 for 13 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 60
# {
#     "dish_look": 0.35955511276434604,
#     "dish_portion": 0.5150807035717992,
#     "dish_recommendation": 0.5609413153505582,
#     "dish_taste": 0.5489170034870762,
#     "environment_cleaness": 0.4837279420593243,
#     "environment_decoration": 0.3980899804263802,
#     "environment_noise": 0.48526049867674487,
#     "environment_space": 0.3925010905207141,
#     "location_distance_from_business_district": 0.23257067832469386,
#     "location_easy_to_find": 0.24785605023151525,
#     "location_traffic_convenience": 0.3152949429802893,
#     "others_overall_experience": 0.5320678154880043,
#     "others_willing_to_consume_again": 0.6743363610597238,
#     "price_cost_effective": 0.6150198229203507,
#     "price_discount": 0.42848971452079787,
#     "price_level": 0.6198936238970956,
#     "service_parking_convenience": 0.36193749863305,
#     "service_serving_speed": 0.4951361613354277,
#     "service_wait_time": 0.30778659082416965,
#     "service_waiters_attitude": 0.5999197494847264
# }
# epoch: 60 LR: 5.9862575912810195e-05, F1_score:0.4587191328278394
# F1-score did not improved from 0.4596552201619102 for 14 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 61
# {
#     "dish_look": 0.364998358368672,
#     "dish_portion": 0.5128354063268654,
#     "dish_recommendation": 0.5528413212535339,
#     "dish_taste": 0.5561634718940344,
#     "environment_cleaness": 0.4831476863006296,
#     "environment_decoration": 0.3988998522094972,
#     "environment_noise": 0.4822806387806856,
#     "environment_space": 0.3896765887741511,
#     "location_distance_from_business_district": 0.23224536945724789,
#     "location_easy_to_find": 0.2467628219270908,
#     "location_traffic_convenience": 0.3245788993605605,
#     "others_overall_experience": 0.5343845198949254,
#     "others_willing_to_consume_again": 0.6728435295819161,
#     "price_cost_effective": 0.61543892015929,
#     "price_discount": 0.43008244408100543,
#     "price_level": 0.6193787936040562,
#     "service_parking_convenience": 0.35897374124620524,
#     "service_serving_speed": 0.49351387440007344,
#     "service_wait_time": 0.3103664968145613,
#     "service_waiters_attitude": 0.6017333678588428
# }
# epoch: 61 LR: 5.3876318321529174e-05, F1_score:0.4590573051146922
# F1-score did not improved from 0.4596552201619102 for 15 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 62
# {
#     "dish_look": 0.36502332759948974,
#     "dish_portion": 0.5181984493288624,
#     "dish_recommendation": 0.556305957307285,
#     "dish_taste": 0.5485723525522985,
#     "environment_cleaness": 0.4856493357616661,
#     "environment_decoration": 0.39928023815362024,
#     "environment_noise": 0.48590327705061376,
#     "environment_space": 0.39266968567304467,
#     "location_distance_from_business_district": 0.23198696652328826,
#     "location_easy_to_find": 0.24657377055562477,
#     "location_traffic_convenience": 0.3245648374980264,
#     "others_overall_experience": 0.532852984003556,
#     "others_willing_to_consume_again": 0.6724433657317728,
#     "price_cost_effective": 0.6148116448021316,
#     "price_discount": 0.4300408055212406,
#     "price_level": 0.6202693100895333,
#     "service_parking_convenience": 0.35750386686024593,
#     "service_serving_speed": 0.49470992426985977,
#     "service_wait_time": 0.3083106223677403,
#     "service_waiters_attitude": 0.6012836604152427
# }
# epoch: 62 LR: 4.848868648937626e-05, F1_score:0.4593477191032571
# F1-score did not improved from 0.4596552201619102 for 16 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 63
# {
#     "dish_look": 0.36107624857852816,
#     "dish_portion": 0.5141086120149774,
#     "dish_recommendation": 0.5583935349843475,
#     "dish_taste": 0.5472056378374887,
#     "environment_cleaness": 0.4836279900644035,
#     "environment_decoration": 0.40002765998805756,
#     "environment_noise": 0.4870288311692429,
#     "environment_space": 0.39038734785217033,
#     "location_distance_from_business_district": 0.23229839031595007,
#     "location_easy_to_find": 0.24602732405869304,
#     "location_traffic_convenience": 0.3231028801077233,
#     "others_overall_experience": 0.5318895577462519,
#     "others_willing_to_consume_again": 0.6727710261431034,
#     "price_cost_effective": 0.611155772357504,
#     "price_discount": 0.4313656073014552,
#     "price_level": 0.618718232014959,
#     "service_parking_convenience": 0.35987178521134894,
#     "service_serving_speed": 0.49371420819084144,
#     "service_wait_time": 0.3090522630002851,
#     "service_waiters_attitude": 0.6010173309745543
# }
# epoch: 63 LR: 4.3639817840438635e-05, F1_score:0.45864201199559423
# F1-score did not improved from 0.4596552201619102 for 17 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 64
# {
#     "dish_look": 0.36954351952116476,
#     "dish_portion": 0.5121441846633956,
#     "dish_recommendation": 0.5541811148045808,
#     "dish_taste": 0.5479192515577106,
#     "environment_cleaness": 0.48176772050465566,
#     "environment_decoration": 0.4000762580059185,
#     "environment_noise": 0.4847610444523178,
#     "environment_space": 0.38933729646898463,
#     "location_distance_from_business_district": 0.23270532841430677,
#     "location_easy_to_find": 0.24587367985498157,
#     "location_traffic_convenience": 0.3238807532236855,
#     "others_overall_experience": 0.5325935442905111,
#     "others_willing_to_consume_again": 0.6706503023699233,
#     "price_cost_effective": 0.6079059557550373,
#     "price_discount": 0.4297468660035011,
#     "price_level": 0.6200391497781961,
#     "service_parking_convenience": 0.35734763076996184,
#     "service_serving_speed": 0.4923588238470213,
#     "service_wait_time": 0.3069286238373213,
#     "service_waiters_attitude": 0.600715134909523
# }
# epoch: 64 LR: 3.9275836056394775e-05, F1_score:0.458023809151635
# F1-score did not improved from 0.4596552201619102 for 18 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 65
# {
#     "dish_look": 0.36186729198688866,
#     "dish_portion": 0.5159671966382733,
#     "dish_recommendation": 0.5613626738839784,
#     "dish_taste": 0.555182583405408,
#     "environment_cleaness": 0.48241410761566983,
#     "environment_decoration": 0.3982100180340242,
#     "environment_noise": 0.4860302090822026,
#     "environment_space": 0.38990637916116605,
#     "location_distance_from_business_district": 0.2311394653269482,
#     "location_easy_to_find": 0.24630096839214619,
#     "location_traffic_convenience": 0.32135524342841143,
#     "others_overall_experience": 0.5349486237922717,
#     "others_willing_to_consume_again": 0.6736416445526621,
#     "price_cost_effective": 0.6148484752195915,
#     "price_discount": 0.43107450322629687,
#     "price_level": 0.6192514526641312,
#     "service_parking_convenience": 0.35888464052611535,
#     "service_serving_speed": 0.49857520628178054,
#     "service_wait_time": 0.3104459214090421,
#     "service_waiters_attitude": 0.6008088289002184
# }
# epoch: 65 LR: 3.53482524507553e-05, F1_score:0.4596107716763614
# F1-score did not improved from 0.4596552201619102 for 19 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 66
# {
#     "dish_look": 0.36702001621214403,
#     "dish_portion": 0.5142532088477797,
#     "dish_recommendation": 0.5613406447259001,
#     "dish_taste": 0.5546341280930979,
#     "environment_cleaness": 0.483678668165989,
#     "environment_decoration": 0.3998807353129089,
#     "environment_noise": 0.4854875255352896,
#     "environment_space": 0.3923792763692069,
#     "location_distance_from_business_district": 0.23216408810730388,
#     "location_easy_to_find": 0.24532040056683152,
#     "location_traffic_convenience": 0.32336781772852896,
#     "others_overall_experience": 0.5328250584794596,
#     "others_willing_to_consume_again": 0.6692861476864232,
#     "price_cost_effective": 0.6157366142344973,
#     "price_discount": 0.4293027753941052,
#     "price_level": 0.620159839807325,
#     "service_parking_convenience": 0.3599703756395751,
#     "service_serving_speed": 0.4911122759551785,
#     "service_wait_time": 0.3065662055441519,
#     "service_waiters_attitude": 0.6020445950232558
# }
# epoch: 66 LR: 3.1813427205679776e-05, F1_score:0.45932651987144757
# F1-score did not improved from 0.4596552201619102 for 20 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# training epoch 67
# {
#     "dish_look": 0.3688887678597304,
#     "dish_portion": 0.5135862396096793,
#     "dish_recommendation": 0.5541191780998325,
#     "dish_taste": 0.5503544185881156,
#     "environment_cleaness": 0.4828044005487503,
#     "environment_decoration": 0.3997968363243264,
#     "environment_noise": 0.4877150183886632,
#     "environment_space": 0.3917665997087869,
#     "location_distance_from_business_district": 0.2314950968710195,
#     "location_easy_to_find": 0.24460165650278007,
#     "location_traffic_convenience": 0.3117325054422584,
#     "others_overall_experience": 0.5329151708791952,
#     "others_willing_to_consume_again": 0.6709530334626173,
#     "price_cost_effective": 0.6152303147981357,
#     "price_discount": 0.42909720959592623,
#     "price_level": 0.6206751332044809,
#     "service_parking_convenience": 0.35838052163772344,
#     "service_serving_speed": 0.49236533173914593,
#     "service_wait_time": 0.3091968451749854,
#     "service_waiters_attitude": 0.6017147586744693
# }
# epoch: 67 LR: 2.8632084485111798e-05, F1_score:0.458369451855531
# F1-score did not improved from 0.4596552201619102 for 21 epochs
# Loading model from ../ckpt/RCNN_0.4596552201619102.pt
# Stop training

# %%
test_arr = np.load("../inputs/X_test.npz")

# %%
test_arr['X']
# Out:
# array([[6631, 1369,    1, ...,  487,    1,    2],
#        [   8,    1,  644, ...,  147,    1,    2],
#        [   1,  430,    1, ...,  479,    1,    2],
#        ...,
#        [   1,  152,   22, ...,  644,    1,    2],
#        [   1,  379,  152, ...,  147,    1,    2],
#        [   1, 1025, 8134, ...,  147,    1,    2]], dtype=int32)

# %%
test_loader = data.DataLoader(torch.from_numpy(test_arr['X']).long(), batch_size=1024, shuffle=False, num_workers=8)

# %%
def pred_test(model, testloader, use_cuda=True):
    model.eval()
    y_pred = defaultdict(list)
    for bx in testloader:
        if use_cuda:
            bx = bx.cuda()
        y_pre = model(bx)
        for col in model.label_list:
            y_label = torch.max(y_pre[col], 1)[1].data
            y_pred[col].extend(y_label.tolist())
    return y_pred

# %%
pred_test = pred_test(model, test_loader)

# %%
import pandas as pd
def load_data_from_csv(file_name, header=0, encoding="utf-8"):

    data_df = pd.read_csv(file_name, header=header, encoding=encoding)

    return data_df

# %%
test = load_data_from_csv("../inputs/sentiment_analysis_testa.csv")

# %%
for col, pred in pred_test.items():
    test[col] = pred
    test[col] -= 2

# %%
test.to_csv("../output/RCNN1.csv", encoding="utf_8_sig", index=False)
